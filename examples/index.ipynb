# %% [markdown]
# # Example:
# - [codon usage module](https://mybinder.org/v2/gh/JingWui/SynBioPython/master?filepath=examples%2Fcodon.ipynb)
# - [genbabel standard files module](https://mybinder.org/v2/gh/JingWui/SynBioPython/master?filepath=examples%2Fgenbabel.ipynb)
# - [lab automation module](https://mybinder.org/v2/gh/JingWui/SynBioPython/master?filepath=examples%2Flab_automation.ipynb)

# %%
# %run genbabel.ipynb
# Out:
# C:\Users\jingwui\AppData\Local\Temp
# Output file:  C:\Users\jingwui\AppData\Local\Temp\pBAD_BLind_AND.sbol
# valid: True
# part_length ['c0', 'p0', 'p1', 'r0', 'c1', 't0', 'p2', 'r1', 'c2', 't1', 'o0']
# <?xml version="1.0" encoding="UTF-8"?>
# <sbml xmlns="http://www.sbml.org/sbml/level3/version1/core" level="3" version="1">
#   <model substanceUnits="mole" timeUnits="second" extentUnits="mole">
#     <listOfUnitDefinitions>
#       <unitDefinition id="per_second">
#         <listOfUnits>
#           <unit kind="second" exponent="-1" scale="0" multiplier="1"/>
#         </listOfUnits>
#       </unitDefinition>
#       <unitDefinition id="per_min">
#         <listOfUnits>
#           <unit kind="second" exponent="-1" scale="0" multiplier="60"/>
#         </listOfUnits>
#       </unitDefinition>
#       <unitDefinition id="molperLmin">
#         <listOfUnits>
#           <unit kind="mole" exponent="1" scale="0" multiplier="1"/>
# ...
